# %%
# First we'll import the os module
# This will allow us to create file paths across operating systems
import os

# Module for reading CSV files
import csv

# %%
csvpath = os.path.join('Resources', 'budget_data.csv')
# Method 2: Improved Reading using CSV module

with open(csvpath) as csvfile:

    # CSV reader specifies delimiter and variable that holds contents
    csvreader = csv.reader(csvfile, delimiter=',')

    print(csvreader)
    
      # Read the header row first (skip this step if there is now header)
    csv_header = next(csvreader)
    csvlineone= next(csvreader)
    csvlineone[0]
    temp_hold = (int(csvlineone[1]))
    total_months= 1
    total_sum = (int(csvlineone[1]))
    change = 0
    #great_in = 0
    #great_de = 0

   #print(total_sum) 
    print("Financial Analysis")
    print("--------------------------------------")

    # Read each row of data after the header
    for row in csvreader:
        current_num=int(row[1])
        total_months+=1
        total_sum += current_num
        change = temp_hold - current_num
        print("change",change)
        print("temp_hold before assigning it again", temp_hold)
        temp_hold = current_num
        print("temp_hold after assigning it again", temp_hold)

        
    print("Total Months :" + str(total_months))
    print("Total :" + str(total_sum))
    #print("Average Change"+ str(total_sum))
    print(total_sum)
# Out:
# ...
# Financial Analysis
# --------------------------------------
# change -116771
# temp_hold before assigning it again 867884
# temp_hold after assigning it again 984655
# change 662642
# temp_hold before assigning it again 984655
# temp_hold after assigning it again 322013
# change 391430
# temp_hold before assigning it again 322013
# temp_hold after assigning it again -69417
# change -379920
# temp_hold before assigning it again -69417
# temp_hold after assigning it again 310503
# change -212354
# temp_hold before assigning it again 310503
# temp_hold after assigning it again 522857
# change -510239
# temp_hold before assigning it again 522857
# temp_hold after assigning it again 1033096
# change 428211
# temp_hold before assigning it again 1033096
# temp_hold after assigning it again 604885
# change 821271
# temp_hold before assigning it again 604885
# temp_hold after assigning it again -216386
# change -693918
# temp_hold before assigning it again -216386
# ...
